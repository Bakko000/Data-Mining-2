# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import cosine
import scipy.stats as sp
import re

# %%
t_s=pd.read_csv('time_series_dataset.csv', skipinitialspace=True, index_col=False)

# %%
t_s
# Out:
#       Unnamed: 0                      ID  \
# 0              0  3HUMNxBQoCPTg2K8wi7oFb
# 1              1  0vgIkHFK8wpogVc1XCi18F
# 2              2  0Av7W8Abdx761b2Ey5wo1u
# 3              3  5KIuAOpwX3UHISVwuBhG2J
# 4              4  1e6YswGTpMvjk21TQAxfXw
# ...          ...                     ...
# 9859        9859  70DoteWv6bCOzJCrgE1OZB
# 9860        9860  5WJtuMqSdxcbuNvouacT37
# 9861        9861  7nvzIA270KiNDRWFbDFYtg
# 9862        9862  54OrSbpVmumMYpo719UOtu
# 9863        9863  7nP1xAbR6A5zyR7HFjuaDQ
#
#                                             Time_Series
# 0     [array([ 768.95392809,  828.02258438,  941.386...
# 1     [array([3230.21111891, 3344.52008121, 3136.686...
# 2     [array([2192.69421881, 1986.90485659, 2082.598...
# 3     [array([1050.2701736 , 1122.23826077, 1176.087...
# 4     [array([2467.43005638, 2222.34486062, 2053.680...
# ...                                                 ...
# 9859  [array([2548.12486155, 2546.78823303, 2649.905...
# ...

# %%
# Funzione per convertire una stringa di time series in un array di valori
def string_to_array(series_string):
    # Estrai i numeri dalla stringa utilizzando regex
    numbers = re.findall(r'[-+]?\d*\.\d+|\d+', series_string)
    array_valori = np.array(numbers)

    # Converti i numeri estratti in un array di float
    return array_valori

# %%
t_s['Time_Series']=t_s['Time_Series'].apply(string_to_array)

# %%
t_s[['Time_Series']]
# Out:
#                                             Time_Series
# 0     [768.95392809, 828.02258438, 941.38630447, 144...
# 1     [3230.21111891, 3344.52008121, 3136.68604971, ...
# 2     [2192.69421881, 1986.90485659, 2082.59886419, ...
# 3     [1050.2701736, 1122.23826077, 1176.08785465, 8...
# 4     [2467.43005638, 2222.34486062, 2053.68002202, ...
# ...                                                 ...
# 9859  [2548.12486155, 2546.78823303, 2649.90570502, ...
# 9860  [2228.44017556, 2254.23282096, 2708.21306667, ...
# 9861  [2744.44416673, 2714.7230879, 2696.45324601, 3...
# 9862  [1679.19150849, 1371.38211376, 1276.83064524, ...
# 9863  [1760.40333559, 1669.68354612, 1690.64028044, ...
#
# [9864 rows x 1 columns]

# %%
for i in t_s['Time_Series']:
    print(type(i))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ...

# %%
df_senza_t_s=pd.read_csv('nuovo_dataset_totale.csv', skipinitialspace=True)

# %%
df_senza_t_s
# Out:
#                             id                                        name  \
# 0       4rjA5kJJWbwU1prXCvg6Fk                                        Grey
# 1       6xzpUzzIquIyUzTLbbgSdI                                      Thrown
# 2       56tXgHlSHCfgmGhwVXNizc                                     Routine
# 3       0s3wIBczp6TdSJ2y8cveJl  Confronted - Anfisa Letyago Stranger Remix
# 4       4PSbDDd1LRYMhqPXvza6I2                             Jupiter Sunrise
# ...                        ...                                         ...
# 109144  0wiDjWz3U1WfwXSrWHXe2b     I'm Good (Blue) - REAPER Extended Remix
# 109145  46n9OJc7LOIVdj8t2l5WA5                            End Of The Night
# 109146  127uq83uGFapbddqiMUKky                     Sexy Bitch (feat. Akon)
# 109147  0ZdUHFxifUJNqo7G4aJzoF                                    Savannah
# 109148  0M4HcGtxIWVVH4rSNp6XhQ                                      Dejalo
#
# ...

# %%
merged_df = t_s.merge(df_senza_t_s, left_on="ID", right_on="id", how="inner")

# %%
merged_df
# Out:
#        Unnamed: 0                      ID  \
# 0               0  3HUMNxBQoCPTg2K8wi7oFb
# 1               1  0vgIkHFK8wpogVc1XCi18F
# 2               1  0vgIkHFK8wpogVc1XCi18F
# 3               2  0Av7W8Abdx761b2Ey5wo1u
# 4               3  5KIuAOpwX3UHISVwuBhG2J
# ...           ...                     ...
# 12781        9860  5WJtuMqSdxcbuNvouacT37
# 12782        9860  5WJtuMqSdxcbuNvouacT37
# 12783        9861  7nvzIA270KiNDRWFbDFYtg
# 12784        9862  54OrSbpVmumMYpo719UOtu
# 12785        9863  7nP1xAbR6A5zyR7HFjuaDQ
#
#                                              Time_Series  \
# 0      [768.95392809, 828.02258438, 941.38630447, 144...
# 1      [3230.21111891, 3344.52008121, 3136.68604971, ...
# 2      [3230.21111891, 3344.52008121, 3136.68604971, ...
# 3      [2192.69421881, 1986.90485659, 2082.59886419, ...
# 4      [1050.2701736, 1122.23826077, 1176.08785465, 8...
# ...                                                  ...
# ...

# %%
for i in merged_df['Time_Series']:
    print(type(i))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ...

# %%
merged_df.to_csv('dataset_finale_timeseries.csv')
